# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import scipy.stats as st

import seaborn as sns
import seaborn.objects as so

# %%
#HYPOTHESIS

#1) Misha
    #HYPOTHESIS 1A - (MISHA)
        #HYBRID CANNABIS TYPES HAVE MORE HAPPY EFFECTS COMPARED TO OTHER TYPES OF CANNABIS (USING EFFECT 1)
    #HYPOTHESIS 1B - (MISHA)
        #there is a significant difference in rating when comparing different types of cannabis
    #HYPOTHESIS 1C - (MISHA)
        #the main effect experienced by consuming any type of cannabis is “relaxed”
    
#2) Kim
    #Does sweet profile cannabis have a higher rating?
        #What Flavor had the max Rating
        #What Flavor has the min Rating
        #What Flavor has the median Rating
    
#3) #Latti
    #Does the location of the breeder impact the rating? Does the location impact the type that is grown?

#4)  Tacha
    #Is there a significant difference in the effects experienced by consumers when they rate the same cannabis type differently? 
    #(Use data to get the ratings of the cannabis type and analyze the effects reported to see if they are consistent.) Do users feel different effects when they use the same type of cannabis(yes). How does this affect how they rate it? Ex: Hybrid- 13 users said it made them aroused. What is the average rating reported by those 13 people? Repeat for a few more effects in Hybrid, Sativa, then Indica.
    #Happiness

# %%
#Import CSV data and view data table
Original_Data = pd.read_csv("new_data.csv",encoding='latin-1')
Original_Data.head()
# Out:
#        Strain    Type  Rating                                     Effects  \
# 0        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 1      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     0.0                                         NaN
#
#                       Flavor                     Breeders     LOCATION
# 0    Spicy/Herbal,Sage,Woody             Medical Seeds Co        Spain
# 1        Earthy,Sweet,Citrus                          NaN          NaN
# 2  Apricot,Citrus,Grapefruit  Canadian LP Delta 9 BioTech       Canada
# 3       Citrus,Earthy,Orange                          NaN  Los Angeles
# 4                        NaN           Mephisto Genetics           NaN

# %%
#Split "Effects" column into different separate columns for manipulation
Original_Data.Effects.str.split(",",expand=True)
# Out:
#              0          1          2          3          4
# 0     Uplifted      Happy    Relaxed  Energetic   Creative
# 1     Creative  Energetic     Tingly   Euphoric    Relaxed
# 2       Tingly   Creative     Hungry    Relaxed   Uplifted
# 3        Happy    Relaxed   Euphoric   Uplifted  Talkative
# 4          NaN        NaN        NaN        NaN        NaN
# ...        ...        ...        ...        ...        ...
# 2346     Happy   Uplifted    Relaxed   Euphoric  Energetic
# 2347   Relaxed      Happy   Euphoric   Uplifted     Sleepy
# 2348   Relaxed     Sleepy  Talkative   Euphoric      Happy
# 2349   Relaxed     Sleepy   Euphoric      Happy     Hungry
# 2350    Hungry    Relaxed   Uplifted      Happy     Sleepy
#
# [2351 rows x 5 columns]

# %%
#Create a dataframe for the different effects and name the column titles
effects = Original_Data.Effects.str.split(",",expand=True)
effects.columns=["effect_1", "effect_2", "effect_3", "effect_4", "effect_5"]
effects.head()
# Out:
#    effect_1   effect_2  effect_3   effect_4   effect_5
# 0  Uplifted      Happy   Relaxed  Energetic   Creative
# 1  Creative  Energetic    Tingly   Euphoric    Relaxed
# 2    Tingly   Creative    Hungry    Relaxed   Uplifted
# 3     Happy    Relaxed  Euphoric   Uplifted  Talkative
# 4       NaN        NaN       NaN        NaN        NaN

# %%
#Create a dataframe for the different flavors and name the column titles
flavors = Original_Data.Flavor.str.split(",",expand=True)
flavors.columns=["flavor_1", "flavor_2", "flavor_3", "flavor_4"]
flavors.head()
# Out:
#        flavor_1 flavor_2    flavor_3 flavor_4
# 0  Spicy/Herbal     Sage       Woody     None
# 1        Earthy    Sweet      Citrus     None
# 2       Apricot   Citrus  Grapefruit     None
# 3        Citrus   Earthy      Orange     None
# 4           NaN      NaN         NaN      NaN

# %%
#Get the data for the flavors
flavors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   flavor_1  2195 non-null   object
#  1   flavor_2  2161 non-null   object
#  2   flavor_3  2117 non-null   object
#  3   flavor_4  43 non-null     object
# dtypes: object(4)
# memory usage: 73.6+ KB

# %%
#Add the new columns for effects and falvors to the original dataframe
pd.concat([Original_Data, effects, flavors], axis=1)
# Out:
#            Strain    Type  Rating                                     Effects  \
# 0            1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 1          100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 2        13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3        24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4      3-Bears-Og  indica     0.0                                         NaN
# ...           ...     ...     ...                                         ...
# 2346      Zeus-Og  hybrid     4.7   Happy,Uplifted,Relaxed,Euphoric,Energetic
# 2347     Zkittlez  indica     4.6      Relaxed,Happy,Euphoric,Uplifted,Sleepy
# 2348  Zombie-Kush  indica     5.0     Relaxed,Sleepy,Talkative,Euphoric,Happy
# 2349    Zombie-Og  indica     4.4        Relaxed,Sleepy,Euphoric,Happy,Hungry
# 2350     Zoom-Pie  indica     4.6        Hungry,Relaxed,Uplifted,Happy,Sleepy
#
#                          Flavor                      Breeders     LOCATION  \
# 0       Spicy/Herbal,Sage,Woody              Medical Seeds Co        Spain
# 1           Earthy,Sweet,Citrus                           NaN          NaN
# 2     Apricot,Citrus,Grapefruit   Canadian LP Delta 9 BioTech       Canada
# 3          Citrus,Earthy,Orange                           NaN  Los Angeles
# 4                           NaN            Mephisto Genetics           NaN
# ...                         ...                           ...          ...
# 2346          Earthy,Woody,Pine    A Greener Today's Dankczar          NaN
# 2347          Sweet,Berry,Grape  3rd Gen Family and Terp Hogz          NaN
# 2348  Earthy,Sweet,Spicy/Herbal                  Ripper Seeds          NaN
# 2349       Sweet,Earthy,Pungent                           NaN          NaN
# 2350       Berry,Earthy,Pungent                           NaN          NaN
#
#       effect_1   effect_2   effect_3   effect_4   effect_5      flavor_1  \
# 0     Uplifted      Happy    Relaxed  Energetic   Creative  Spicy/Herbal
# 1     Creative  Energetic     Tingly   Euphoric    Relaxed        Earthy
# 2       Tingly   Creative     Hungry    Relaxed   Uplifted       Apricot
# 3        Happy    Relaxed   Euphoric   Uplifted  Talkative        Citrus
# 4          NaN        NaN        NaN        NaN        NaN           NaN
# ...        ...        ...        ...        ...        ...           ...
# 2346     Happy   Uplifted    Relaxed   Euphoric  Energetic        Earthy
# 2347   Relaxed      Happy   Euphoric   Uplifted     Sleepy         Sweet
# 2348   Relaxed     Sleepy  Talkative   Euphoric      Happy        Earthy
# 2349   Relaxed     Sleepy   Euphoric      Happy     Hungry         Sweet
# 2350    Hungry    Relaxed   Uplifted      Happy     Sleepy         Berry
#
#      flavor_2      flavor_3 flavor_4
# 0        Sage         Woody     None
# 1       Sweet        Citrus     None
# 2      Citrus    Grapefruit     None
# 3      Earthy        Orange     None
# 4         NaN           NaN      NaN
# ...       ...           ...      ...
# 2346    Woody          Pine     None
# 2347    Berry         Grape     None
# 2348    Sweet  Spicy/Herbal     None
# 2349   Earthy       Pungent     None
# 2350   Earthy       Pungent     None
#
# [2351 rows x 16 columns]

# %%
#Rename dataframe to OD2 to keep original dataframe for future reference
OD2=pd.concat([Original_Data, effects, flavors], axis=1)
OD2.head()
# Out:
#        Strain    Type  Rating                                     Effects  \
# 0        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 1      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     0.0                                         NaN
#
#                       Flavor                     Breeders     LOCATION  \
# 0    Spicy/Herbal,Sage,Woody             Medical Seeds Co        Spain
# 1        Earthy,Sweet,Citrus                          NaN          NaN
# 2  Apricot,Citrus,Grapefruit  Canadian LP Delta 9 BioTech       Canada
# 3       Citrus,Earthy,Orange                          NaN  Los Angeles
# 4                        NaN           Mephisto Genetics           NaN
#
#    effect_1   effect_2  effect_3   effect_4   effect_5      flavor_1 flavor_2  \
# 0  Uplifted      Happy   Relaxed  Energetic   Creative  Spicy/Herbal     Sage
# 1  Creative  Energetic    Tingly   Euphoric    Relaxed        Earthy    Sweet
# 2    Tingly   Creative    Hungry    Relaxed   Uplifted       Apricot   Citrus
# 3     Happy    Relaxed  Euphoric   Uplifted  Talkative        Citrus   Earthy
# 4       NaN        NaN       NaN        NaN        NaN           NaN      NaN
#
#      flavor_3 flavor_4
# 0       Woody     None
# 1      Citrus     None
# 2  Grapefruit     None
# 3      Orange     None
# 4         NaN      NaN

# %%
#Get data on new dataframe
#flavor_4 only has 43 non-null datapoints and location has 614. 
OD2["num_effects"]=OD2.Effects.str.count(",")+1
OD2["num_flavors"]=OD2.Flavor.str.count(",")+1
OD2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Strain       2351 non-null   object
#  1   Type         2351 non-null   object
#  2   Rating       2351 non-null   float64
#  3   Effects      2264 non-null   object
#  4   Flavor       2195 non-null   object
#  5   Breeders     1165 non-null   object
#  6   LOCATION     614 non-null    object
#  7   effect_1     2264 non-null   object
#  8   effect_2     2254 non-null   object
#  9   effect_3     2239 non-null   object
#  10  effect_4     2212 non-null   object
#  11  effect_5     2180 non-null   object
#  12  flavor_1     2195 non-null   object
#  13  flavor_2     2161 non-null   object
#  14  flavor_3     2117 non-null   object
#  15  flavor_4     43 non-null     object
#  16  num_effects  2264 non-null   float64
#  17  num_flavors  2195 non-null   float64
# dtypes: float64(3), object(15)
# memory usage: 330.7+ KB

# %%
#Flavor #4 only has 43 non-null values therefore they need to be removed
#Create new dataframe after droping flavor 4
OD2=OD2.drop(columns=["flavor_4"])
OD3=OD2.dropna(how="any")
OD3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 0 to 2341
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Strain       501 non-null    object
#  1   Type         501 non-null    object
#  2   Rating       501 non-null    float64
#  3   Effects      501 non-null    object
#  4   Flavor       501 non-null    object
#  5   Breeders     501 non-null    object
#  6   LOCATION     501 non-null    object
#  7   effect_1     501 non-null    object
#  8   effect_2     501 non-null    object
#  9   effect_3     501 non-null    object
#  10  effect_4     501 non-null    object
#  11  effect_5     501 non-null    object
#  12  flavor_1     501 non-null    object
#  13  flavor_2     501 non-null    object
#  14  flavor_3     501 non-null    object
#  15  num_effects  501 non-null    float64
#  16  num_flavors  501 non-null    float64
# dtypes: float64(3), object(14)
# memory usage: 70.5+ KB

# %%
#We droped 12% of null values so 88% of our data is valid
#(2351-2053)/2351

# %%
#Find the total count for each Type of cannabis
OD3.Type.value_counts()
# Out:
# Type
# hybrid    236
# indica    157
# sativa    108
# Name: count, dtype: int64

# %%
#Displat the total count of for each Type of cannibis in a bar graph
count_types_plot = sns.countplot(x="Type", data=OD3)

count_types_plot.set_xticklabels(count_types_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Total Values for each Type of Cannabis")
plt.tight_layout()
plt.show()

# %%
#HYPOTHESIS 1A - (MISHA)
#HYBRID CANNABIS TYPES HAVE MORE HAPPY EFFECTS COMPARED TO OTHER TYPES OF CANNABIS (USING EFFECT 1)

# %%
#Total count of each effect per Type lised within effect_1
OD3.groupby(["Type", "effect_1"]).size()
# Out:
# Type    effect_1
# hybrid  Aroused        4
#         Creative       6
#         Energetic      4
#         Euphoric      34
#         Focused        7
#         Happy         63
#         Hungry         2
#         Relaxed       74
#         Sleepy         2
#         Talkative      7
#         Tingly         4
#         Uplifted      29
# indica  Aroused        2
#         Creative       2
#         Euphoric      15
#         Focused        1
#         Giggly         1
#         Happy          8
#         Hungry         1
#         Relaxed      112
#         Sleepy        10
#         Talkative      1
#         Uplifted       4
# sativa  Aroused        3
#         Creative       5
#         Energetic      6
#         Euphoric      21
#         Focused        4
#         Giggly         1
#         Happy         31
#         Hungry         1
#         Relaxed        9
#         Sleepy         1
#         Talkative      2
#         Uplifted      24
# dtype: int64

# %%
#Create new dataframe with Type and Effects (Using EFFECT_1)
t_e1=OD3.groupby(["Type", "effect_1"]).size()

h11_df=pd.DataFrame(t_e1)
h11_df.head
# Out:
# <bound method NDFrame.head of                     0
# Type   effect_1
# hybrid Aroused      4
#        Creative     6
#        Energetic    4
#        Euphoric    34
#        Focused      7
#        Happy       63
#        Hungry       2
#        Relaxed     74
#        Sleepy       2
#        Talkative    7
#        Tingly       4
#        Uplifted    29
# indica Aroused      2
#        Creative     2
#        Euphoric    15
#        Focused      1
#        Giggly       1
#        Happy        8
#        Hungry       1
#        Relaxed    112
#        Sleepy      10
#        Talkative    1
#        Uplifted     4
# sativa Aroused      3
#        Creative     5
#        Energetic    6
#        Euphoric    21
#        Focused      4
#        Giggly       1
#        Happy       31
#        Hungry       1
#        Relaxed      9
#        Sleepy       1
#        Talkative    2
#        Uplifted    24>

# %%
#Create Donut/Pie Charts for each type of cannabies to display how many "Happy" Effects they each have (Use Effect 1)

# %%
#HYBRID-locate Hybrid from Data Frame Above
hybrid_e1=h11_df.loc["hybrid"]
hybrid_e1
# Out:
#             0
# effect_1
# Aroused     4
# Creative    6
# Energetic   4
# Euphoric   34
# Focused     7
# Happy      63
# Hungry      2
# Relaxed    74
# Sleepy      2
# Talkative   7
# Tingly      4
# Uplifted   29

# %%
#HYBRID
#Create donut charts for each type of cannabies to display how many "Happy" Effects they each have (Use Effect 1)
hybrid_e1.plot(kind="pie",autopct="%1.1f%%",subplots=True,startangle=1000,fontsize=6)

plt.title("Effect 1 for Hybrid Type Cannabis",fontweight="bold",fontsize=14)
plt.axis("equal")
plt.tight_layout()
#plt.figure(figsize=(5,50))
plt.legend(loc='upper right',fontsize=7)

# Draw circle
center_circle = plt.Circle((0, 0), 0.7, fc='white')
fig = plt.gcf()
 
#Adding circle in pie chart
fig.gca().add_artist(center_circle)

#Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

#Step 4, is to show or save it
plt.show()

# %%
#INDICA DATA FRAME -locate Indica from dataframe above
indica_e1=h11_df.loc["indica"]
indica_e1
# Out:
#              0
# effect_1
# Aroused      2
# Creative     2
# Euphoric    15
# Focused      1
# Giggly       1
# Happy        8
# Hungry       1
# Relaxed    112
# Sleepy      10
# Talkative    1
# Uplifted     4

# %%
#INDICA
#Create donut charts for each type of cannabies to display how many "Happy" Effects they each have (Use Effect 1)
explode = (0.5,1.5,0,0,1,0,0,0,0,0,0.75)

indica_e1.plot(kind="pie",autopct="%1.1f%%",subplots=True,startangle=1000,explode=explode,fontsize=7)



plt.title("Effect 1 for Indica Type Cannabis",fontweight="bold",fontsize=12)
plt.axis("equal")
plt.tight_layout()
#plt.figure(figsize=(5,50))
plt.legend(loc='upper left',fontsize=7)


#Tells matplotlib that we want a pie chart with equal axis
plt.axis("equal")

#Step 4, is to show or save it
plt.show()

# %%
#SATIVA DATA FRAME - locate Sativa from dataframe above
sativa_e1=h11_df.loc["sativa"]
sativa_e1
# Out:
#             0
# effect_1
# Aroused     3
# Creative    5
# Energetic   6
# Euphoric   21
# Focused     4
# Giggly      1
# Happy      31
# Hungry      1
# Relaxed     9
# Sleepy      1
# Talkative   2
# Uplifted   24

# %%
#SATIVA
#Create donut charts for each type of cannabies to display how many "Happy" Effects they each have (Use Effect 1)
sativa_e1.plot(kind="pie",autopct="%1.1f%%",subplots=True,startangle=1000,fontsize=7)

plt.title("Effect 1 for Sativa Type Cannabis",fontweight="bold",fontsize=14)
plt.axis("equal")
plt.tight_layout()
#plt.figure(figsize=(5,50))
plt.legend(loc='lower right',fontsize=6)

#Draw circle
center_circle = plt.Circle((0, 0), 0.7, fc='white')
fig = plt.gcf()
 
#Adding circle in pie chart
fig.gca().add_artist(center_circle)

#Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

#Step 4, is to show or save it
plt.show()

# %%
#Open OD3 To see column names for next plots
OD3.head()
# Out:
#          Strain    Type  Rating                                    Effects  \
# 0          1024  sativa     4.4  Uplifted,Happy,Relaxed,Energetic,Creative
# 2      13-Dawgs  hybrid     4.2    Tingly,Creative,Hungry,Relaxed,Uplifted
# 10     501St-Og  hybrid     4.5    Relaxed,Euphoric,Sleepy,Happy,Talkative
# 11  5Th-Element  indica     4.4  Relaxed,Focused,Euphoric,Uplifted,Aroused
# 13  8-Ball-Kush  indica     4.3   Relaxed,Uplifted,Happy,Creative,Euphoric
#
#                        Flavor                     Breeders  \
# 0     Spicy/Herbal,Sage,Woody             Medical Seeds Co
# 2   Apricot,Citrus,Grapefruit  Canadian LP Delta 9 BioTech
# 10          Earthy,Pine,Skunk          Rare Dankness Seeds
# 11          Earthy,Woody,Pine              Elemental Seeds
# 13         Citrus,Earthy,Pine                Barney's Farm
#
#                          LOCATION  effect_1  effect_2  effect_3   effect_4  \
# 0                           Spain  Uplifted     Happy   Relaxed  Energetic
# 2                          Canada    Tingly  Creative    Hungry    Relaxed
# 10                       Colorado   Relaxed  Euphoric    Sleepy      Happy
# 11                     California   Relaxed   Focused  Euphoric   Uplifted
# 13  Amsterdam, Westmont, Illinois   Relaxed  Uplifted     Happy   Creative
#
#      effect_5      flavor_1 flavor_2    flavor_3  num_effects  num_flavors
# 0    Creative  Spicy/Herbal     Sage       Woody          5.0          3.0
# 2    Uplifted       Apricot   Citrus  Grapefruit          5.0          3.0
# 10  Talkative        Earthy     Pine       Skunk          5.0          3.0
# 11    Aroused        Earthy    Woody        Pine          5.0          3.0
# 13   Euphoric        Citrus   Earthy        Pine          5.0          3.0

# %%
#HYPOTHESIS 1B - (MISHA)
#There is a significant difference in rating when comparing different types of cannabis

# %%
#Create a box plot with types and ratings
sns.boxplot(data=OD3,x="Type",y="Rating")
plt.show()

# %%
#Get statistical values (mean and variance) for all three types according to their rating
OD3.groupby(["Type"]).agg({"Rating":["mean","var"]})
# Out:
#           Rating
#             mean       var
# Type
# hybrid  4.398305  0.257955
# indica  4.455414  0.085307
# sativa  4.435185  0.097442

# %%
#Create a violin chart to display if there is any significant difference in rating
violini=sns.violinplot(data=OD3,x="Type",y="Rating",fontsize=5,legend='auto')
plt.show()

# %%
#Calculate P values to compare all three
#First separate ratings by type and then compare them to each other

grp0=OD3.loc[OD3.Type=="sativa","Rating"]
grp1=OD3.loc[OD3.Type=="hybrid","Rating"]
grp2=OD3.loc[OD3.Type=="indica","Rating"]

# %%
#Compare Sativa vs Hybrid
#P value greater than 0.05 means there is no statistical signifcance 
st.ttest_ind(grp0,grp1)
# Out:
# TtestResult(statistic=0.6965064730155417, pvalue=0.48658481052453917, df=342.0)

# %%
#Compare Sativa vs Indica
#P value greater than 0.05 means there is no statistical signifcance 
st.ttest_ind(grp0,grp2)
# Out:
# TtestResult(statistic=-0.5386418658960523, pvalue=0.5905896023937005, df=263.0)

# %%
#Compare Hybrid vs Indica
#P value greater than 0.05 means there is no statistical signifcance 
st.ttest_ind(grp1,grp2)
# Out:
# TtestResult(statistic=-1.2752629761607839, pvalue=0.2029733692729021, df=391.0)

# %%
#Compare all three and get P-Value
#P value greater than 0.05 means there is no statistical signifcance 
st.f_oneway(grp0,grp1,grp2)
# Out:
# F_onewayResult(statistic=0.9571357342086968, pvalue=0.3846963878282835)

# %%
#HYPOTHESIS 1C - (MISHA)
#The main effect experienced by consuming any type of cannabis is “relaxed”

# %%
#Total count of effects reported on EFFECT 1-Combining all Types
count_plot = sns.countplot(x="effect_1", data=OD3)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Counts of Effect 1 for All Cannabis Types")
plt.tight_layout()
plt.show()

# %%
#Total count of effects - EFFECT 2
count_plot = sns.countplot(x="effect_2", data=OD3)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Counts of Effect 2 for All Cannabis Types")
plt.tight_layout()
plt.show()

# %%
#TOTAL count of effects - EFFECT 3
count_plot = sns.countplot(x="effect_3", data=OD3)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Counts of Effect 3 for All Cannabis Types")
plt.tight_layout()
plt.show()

# %%
#Total count of effects - EFFECT 4
count_plot = sns.countplot(x="effect_4", data=OD3)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Counts of Effect 4 for All Cannabis Types")
plt.tight_layout()
plt.show()

# %%
#Total count of effects - EFFECT 5
count_plot = sns.countplot(x="effect_5", data=OD3)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=40, ha="right")
plt.title("Counts of Effect 5 for All Cannabis Types")
plt.tight_layout()
plt.show()

# %%
#HYPOTHESIS 2 (Kim)
    #What flavors of cannabis have a higher rating?
        #What Flavor had the Max Rating
        #What Flavor has the min Rating
        #What Flavor has the median Rating

# %%
#Group data by rating then count the number of flavor_1 per rating
OD3.groupby(["Rating", "flavor_1"]).size()
# Out:
# Rating  flavor_1
# 0.0     Diesel      1
#         Pungent     1
# 3.3     Cheese      1
#         Sweet       1
# 3.5     Citrus      1
#                    ..
# 5.0     Minty       3
#         Pepper      1
#         Pungent     1
#         Sweet       9
#         Tropical    1
# Length: 182, dtype: int64

# %%
# Create a scatter plot of flavor 1 vs rating
OD3.plot(kind = 'scatter', x = 'flavor_1', y = 'Rating', figsize=(20, 10), rot=90)
plt.title("Flavor 1 Ratings")
plt.xlabel("Flavor 1")
plt.ylabel("Ratings")
plt.tight_layout()
plt.show()

# %%
# Create a scatter plot of flavor 2 vs rating
OD3.plot(kind = 'scatter', x = 'flavor_2', y = 'Rating', figsize=(20, 10), rot=90)
plt.title("Flavor 2 Ratings")
plt.xlabel("Flavor 2")
plt.ylabel("Ratings")
plt.tight_layout()
plt.show()

# %%
# Create a scatter plot of flavor 3 vs rating
OD3.plot(kind = 'scatter', x = 'flavor_3', y = 'Rating', figsize=(20, 10), rot=90)
plt.title("Flavor 3 Ratings")
plt.xlabel("Flavor 3")
plt.ylabel("Ratings")
plt.tight_layout()
plt.show()

# %%
#Find the average rating per flavor of flavor 1 profile
per_flavor1_rating = OD3.groupby("flavor_1")
per_flavor1_rating = per_flavor1_rating["Rating"].mean()
per_flavor1_rating
# Out:
# flavor_1
# Ammonia         4.766667
# Apple           4.800000
# Apricot         4.200000
# Berry           4.436000
# Blue            3.800000
# Blueberry       4.512500
# Butter          4.800000
# Cheese          4.183333
# Chemical        4.700000
# Citrus          4.386275
# Coffee          4.375000
# Diesel          4.188235
# Earthy          4.417187
# Flowery         4.585714
# Grape           4.425000
# Grapefruit      4.000000
# Honey           4.700000
# Lavender        4.150000
# Lemon           4.576190
# Lime            4.650000
# Mango           4.450000
# Menthol         4.550000
# Minty           4.783333
# Orange          4.500000
# Pepper          4.533333
# Pine            4.570000
# Pineapple       4.475000
# Plum            4.300000
# Pungent         4.338095
# Rose            4.650000
# Sage            4.200000
# Skunk           4.380000
# Spicy/Herbal    4.218750
# Strawberry      4.485714
# Sweet           4.427473
# Tropical        4.500000
# Vanilla         4.300000
# Violet          4.800000
# Woody           4.257143
# Name: Rating, dtype: float64

# %%
#Total count of flavors in flavor 1 profile
per_flavor1_rating.count()
# Out:
# 39

# %%
#Mean of all ratings listed in flavor 1 profile
per_flavor1_rating.mean()
# Out:
# 4.4454088113055885

# %%
#Mode of all ratings listed in flavor 1 profile
per_flavor1_rating.mode()
# Out:
# 0    4.4
# Name: Rating, dtype: float64

# %%
#Minimum rating from all ratings listed in flavor 1 profile
per_flavor1_rating.min()
# Out:
# 3.8

# %%
#Maximum rating from all ratings listed in flavor 1 profile
per_flavor1_rating.max()
# Out:
# 4.8

# %%
#Create a box plot with flavors and ratings from flavor 1 profile
plt.figure(figsize=(30,20))
box_plot_f1 = sns.boxplot(data=OD3,x="flavor_1",y="Rating")
box_plot_f1.set_xticklabels(box_plot_f1.get_xticklabels(), rotation=90, fontsize=20)
box_plot_f1.set_yticklabels(box_plot_f1.get_yticklabels(), fontsize=20)
plt.title("Flavor 1 ratings", fontsize=30)
plt.xlabel("Flavors", fontsize=30)
plt.ylabel("Ratings", fontsize=30)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/08/qq4d60ys4rb0q8mws79mv_w00000gp/T/ipykernel_25612/2972255198.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box_plot_f1.set_yticklabels(box_plot_f1.get_yticklabels(), fontsize=20)

# %%
#Find the average rating per flavor of flavor 2 profile
per_flavor2_rating = OD3.groupby("flavor_2")
per_flavor2_rating = per_flavor2_rating["Rating"].mean()
per_flavor2_rating
# Out:
# flavor_2
# Ammonia         4.600000
# Apple           4.250000
# Berry           4.469565
# Blue            4.300000
# Blueberry       4.214286
# Cheese          4.340000
# Chemical        4.575000
# Citrus          4.477778
# Coffee          4.333333
# Diesel          4.425000
# Earthy          4.424286
# Flowery         4.340909
# Grape           4.457143
# Grapefruit      4.333333
# Honey           4.475000
# Lavender        4.440000
# Lemon           4.384615
# Lime            4.750000
# Mango           4.500000
# Menthol         4.000000
# Mint            4.400000
# Minty           4.375000
# Nutty           4.400000
# Orange          4.200000
# Pepper          4.366667
# Pine            4.500000
# Pineapple       4.500000
# Pungent         4.364151
# Rose            4.000000
# Sage            4.450000
# Skunk           4.441667
# Spicy/Herbal    4.313043
# Strawberry      5.000000
# Sweet           4.513158
# Tea             4.450000
# Tree            4.700000
# Tropical        4.558333
# Vanilla         4.400000
# Violet          4.650000
# Woody           4.254167
# Name: Rating, dtype: float64

# %%
#Total count of flavors in flavor 2 profile
per_flavor2_rating.count()
# Out:
# 40

# %%
#Mean of all ratings listed in flavor 2 profile
per_flavor2_rating.mean()
# Out:
# 4.423160851820045

# %%
#Mode of all ratings listed in flavor 2 profile
per_flavor2_rating.mode()
# Out:
# 0    4.5
# Name: Rating, dtype: float64

# %%
#Minimum rating from all ratings listed in flavor 2 profile
per_flavor2_rating.min()
# Out:
# 4.0

# %%
#Maximum rating from all ratings listed in flavor 2 profile
per_flavor2_rating.max()
# Out:
# 5.0

# %%
#Create a box plot with flavors and ratings from flavor 2 profile
plt.figure(figsize=(30,20))
box_plot_f2 = sns.boxplot(data=OD3,x="flavor_2",y="Rating")
box_plot_f2.set_xticklabels(box_plot_f2.get_xticklabels(), rotation=90, fontsize=20)
box_plot_f2.set_yticklabels(box_plot_f2.get_yticklabels(), fontsize=20)
plt.title("Flavor 2 ratings", fontsize=30)
plt.xlabel("Flavor", fontsize=30)
plt.ylabel("Ratings", fontsize=30)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/08/qq4d60ys4rb0q8mws79mv_w00000gp/T/ipykernel_25612/2711513370.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box_plot_f2.set_yticklabels(box_plot_f2.get_yticklabels(), fontsize=20)

# %%
#Find the average rating per flavor of flavor 3 profile
per_flavor3_rating = OD3.groupby("flavor_3")
per_flavor3_rating = per_flavor3_rating["Rating"].mean()
per_flavor3_rating
# Out:
# flavor_3
# Ammonia         4.340000
# Apricot         5.000000
# Berry           4.500000
# Blue            3.700000
# Blueberry       4.500000
# Butter          4.350000
# Cheese          4.316667
# Chemical        4.325000
# Citrus          4.575862
# Coffee          4.733333
# Diesel          4.513333
# Earthy          4.392424
# Flowery         4.437143
# Fruit           4.700000
# Grape           4.580000
# Grapefruit      4.412500
# Honey           4.633333
# Lavender        4.500000
# Lemon           4.313333
# Lime            4.740000
# Mango           4.500000
# Menthol         4.533333
# Mint            4.766667
# Minty           4.800000
# Nutty           4.600000
# Orange          4.671429
# Pear            4.200000
# Pepper          4.320000
# Pine            4.255172
# Pineapple       5.000000
# Pungent         4.440000
# Rose            4.633333
# Sage            4.233333
# Skunk           4.450000
# Spicy/Herbal    4.469565
# Strawberry      4.100000
# Sweet           4.350847
# Tar             4.600000
# Tea             4.040000
# Tobacco         4.250000
# Tree            4.433333
# Tropical        4.500000
# Vanilla         4.450000
# Violet          4.000000
# Woody           4.377778
# Name: Rating, dtype: float64

# %%
#Mean of all ratings listed in flavor 3 profile
per_flavor3_rating.mean()
# Out:
# 4.456393791256677

# %%
#Total count of flavors in flavor 3 profile
per_flavor3_rating.count()
# Out:
# 45

# %%
#Mode of all ratings listed in flavor 3 profile
per_flavor3_rating.mode()
# Out:
# 0    4.5
# Name: Rating, dtype: float64

# %%
#Minimum rating from all ratings listed in flavor 3 profile
per_flavor3_rating.min()
# Out:
# 3.7

# %%
#Maximum rating from all ratings listed in flavor 3 profile
per_flavor3_rating.max()
# Out:
# 5.0

# %%
#Create a box plot with flavors and ratings from flavor 3 profile
plt.figure(figsize=(30,20))
box_plot_f3 = sns.boxplot(data=OD3,x="flavor_3",y="Rating")
box_plot_f3.set_xticklabels(box_plot_f3.get_xticklabels(), rotation=90, fontsize=20)
box_plot_f3.set_yticklabels(box_plot_f3.get_yticklabels(), fontsize=20)
plt.title("Flavor 3 ratings", fontsize=30)
plt.xlabel("Flavor", fontsize=30)
plt.ylabel("Ratings", fontsize=30)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/08/qq4d60ys4rb0q8mws79mv_w00000gp/T/ipykernel_25612/3567128033.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box_plot_f3.set_yticklabels(box_plot_f3.get_yticklabels(), fontsize=20)

# %%
#What flavor has min rating?
#Grouped data by ratings and aggregated the group by min rating
OD3.groupby('Rating').agg('min')
# Out:
#                       Strain    Type  \
# Rating
# 0.0                      Mc1  hybrid
# 3.3             Cheeseburger  hybrid
# 3.5            Golden-Tangie  hybrid
# 3.7              Bakerstreet  hybrid
# 3.8          Alien-Abduction  hybrid
# 3.9                  African  hybrid
# 4.0            Big-Holy-Nina  hybrid
# 4.1            Ace-Of-Spades  hybrid
# 4.2                 13-Dawgs  hybrid
# 4.3              8-Ball-Kush  hybrid
# 4.4                     1024  hybrid
# 4.5                 501St-Og  hybrid
# 4.6              Afghani-Cbd  hybrid
# 4.7                 91-Krypt  hybrid
# 4.8        Afternoon-Delight  hybrid
# 4.9          Bubba-Tom-Hayes  hybrid
# 5.0     Blueberry-Space-Cake  hybrid
#
#                                             Effects  \
# Rating
# 0.0         Hungry,Aroused,Tingly,Uplifted,Creative
# 3.3        Talkative,Creative,Euphoric,Happy,Hungry
# 3.5          Focused,Happy,Aroused,Energetic,Tingly
# 3.7       Aroused,Tingly,Uplifted,Creative,Euphoric
# 3.8       Euphoric,Happy,Hungry,Talkative,Energetic
# 3.9      Energetic,Happy,Creative,Uplifted,Euphoric
# 4.0        Creative,Tingly,Euphoric,Hungry,Uplifted
# 4.1      Energetic,Focused,Relaxed,Talkative,Tingly
# 4.2     Creative,Euphoric,Tingly,Uplifted,Energetic
# 4.3       Euphoric,Creative,Energetic,Happy,Aroused
# 4.4       Aroused,Happy,Uplifted,Creative,Energetic
# 4.5        Creative,Aroused,Happy,Euphoric,Uplifted
# 4.6        Creative,Focused,Uplifted,Happy,Euphoric
# 4.7       Aroused,Creative,Energetic,Euphoric,Happy
# 4.8        Aroused,Tingly,Uplifted,Euphoric,Focused
# 4.9       Creative,Energetic,Happy,Aroused,Uplifted
# 5.0      Aroused,Energetic,Euphoric,Focused,Relaxed
#
#                              Flavor                Breeders  \
# Rating
# 0.0       Diesel,Spicy/Herbal,Sweet    TGA Subcool Genetics
# 3.3               Cheese,Pepper,Tea          Cannasol Farms
# 3.5            Citrus,Orange,Earthy            Calyx Garden
# 3.7     Berry,Blueberry,Blue,Cheese  Canadian LP Tweed, Inc
# 3.8      Blue,Cheese,Cheese,Pungent               Ace Seeds
# 3.9            Coffee,Berry,Flowery            Buddha Seeds
# 4.0             Berry,Pungent,Sweet     Apothecary Genetics
# 4.1              Berry,Woody,Earthy          Alien Genetics
# 4.2       Apricot,Citrus,Grapefruit               Ace Seeds
# 4.3             Ammonia,Citrus,Rose     Apothecary Genetics
# 4.4           Berry,Sweet,Blueberry          Alien Genetics
# 4.5         Berry,Flowery,Blueberry          Alien Genetics
# 4.6            Berry,Earthy,Pungent      Archive Seeds Bank
# 4.7              Berry,Earthy,Sweet          Alien Genetics
# 4.8               Apple,Sweet,Minty              710 Savant
# 4.9              Citrus,Pepper,Lime           Barney's Farm
# 5.0             Ammonia,Diesel,Mint               Ace Seeds
#
#                              LOCATION   effect_1   effect_2  effect_3  \
# Rating
# 0.0               Seattle, Washington     Hungry    Aroused    Tingly
# 3.3                            Canada  Talkative   Creative  Euphoric
# 3.5              Humboldt, California    Focused      Happy   Aroused
# 3.7                           Arizona    Aroused     Giggly  Creative
# 3.8                            Africa   Euphoric      Happy  Creative
# 3.9                            Africa  Energetic  Energetic   Aroused
# 4.0     Afghanistan, Hawaii and Nepal   Creative    Aroused   Aroused
# 4.1            Amsterdam, Netherlands  Energetic  Energetic  Euphoric
# 4.2     Afghanistan, Hawaii and Nepal   Creative   Creative  Creative
# 4.3                       Afghanistan   Euphoric   Creative  Creative
# 4.4     Afghanistan, Hawaii and Nepal    Aroused   Creative  Creative
# 4.5     Afghanistan, Hawaii and Nepal   Creative    Aroused   Aroused
# 4.6     Afghanistan, Hawaii and Nepal   Creative    Aroused   Aroused
# 4.7     Afghanistan, Hawaii and Nepal    Aroused    Aroused   Aroused
# 4.8     Afghanistan, Hawaii and Nepal    Aroused   Creative  Creative
# 4.9                       Afghanistan   Creative   Creative  Creative
# 5.0                         Amsterdam    Aroused    Aroused  Creative
#
#         effect_4   effect_5 flavor_1      flavor_2  flavor_3  num_effects  \
# Rating
# 0.0     Creative   Creative   Diesel  Spicy/Herbal      Pine          5.0
# 3.3      Aroused   Creative   Cheese         Grape   Flowery          5.0
# 3.5     Creative  Energetic   Citrus         Berry    Earthy          5.0
# 3.7     Creative   Euphoric    Berry     Blueberry      Blue          5.0
# 3.8      Aroused   Creative     Blue         Berry    Cheese          5.0
# 3.9     Euphoric   Creative   Coffee         Berry  Chemical          5.0
# 4.0     Creative   Creative    Berry     Blueberry   Ammonia          5.0
# 4.1      Aroused    Aroused    Berry     Blueberry    Diesel          5.0
# 4.2     Creative   Creative  Apricot         Apple     Berry          5.0
# 4.3      Aroused    Aroused  Ammonia         Apple   Ammonia          5.0
# 4.4      Aroused    Aroused    Berry         Berry     Berry          5.0
# 4.5      Aroused   Creative    Berry         Berry   Ammonia          5.0
# 4.6      Aroused    Aroused    Berry       Ammonia     Berry          5.0
# 4.7      Aroused   Creative    Berry         Berry     Berry          5.0
# 4.8     Creative    Aroused    Apple         Berry     Berry          5.0
# 4.9      Aroused    Aroused   Citrus         Berry   Ammonia          5.0
# 5.0     Creative    Aroused  Ammonia         Berry   Apricot          5.0
#
#         num_flavors
# Rating
# 0.0             3.0
# 3.3             3.0
# 3.5             3.0
# 3.7             3.0
# 3.8             3.0
# 3.9             3.0
# 4.0             3.0
# 4.1             3.0
# 4.2             3.0
# 4.3             3.0
# 4.4             3.0
# 4.5             3.0
# 4.6             3.0
# 4.7             3.0
# 4.8             3.0
# 4.9             3.0
# 5.0             3.0

# %%
#What flavor has max rating?
#Grouped data by ratings and aggregated the group by max rating
OD3.groupby('Rating').agg('max')
# Out:
#                            Strain    Type  \
# Rating
# 0.0                     The-Wills  hybrid
# 3.3                 Lethal-Purple  hybrid
# 3.5                   Purple-Goat  sativa
# 3.7                      Malakoff  sativa
# 3.8                 Wild-Thailand  sativa
# 3.9                    Sweet-Nina  sativa
# 4.0                         Waldo  sativa
# 4.1                     Super-Bud  sativa
# 4.2                         Yummy  sativa
# 4.3                   White-Widow  sativa
# 4.4                   White-Skunk  sativa
# 4.5                      Wreckage  sativa
# 4.6                  White-Knight  sativa
# 4.7                    White-Gold  sativa
# 4.8                   Walker-Kush  sativa
# 4.9                           Wmd  sativa
# 5.0     Tangerine-Trainwreck-Haze  sativa
#
#                                             Effects  \
# Rating
# 0.0     Talkative,Tingly,Uplifted,Creative,Euphoric
# 3.3        Tingly,Uplifted,Relaxed,Aroused,Creative
# 3.5     Uplifted,Happy,Talkative,Creative,Energetic
# 3.7        Relaxed,Happy,Talkative,Uplifted,Focused
# 3.8          Relaxed,Sleepy,Hungry,Aroused,Uplifted
# 3.9      Talkative,Happy,Uplifted,Focused,Energetic
# 4.0       Talkative,Uplifted,Euphoric,Happy,Relaxed
# 4.1         Uplifted,Happy,Relaxed,Tingly,Energetic
# 4.2          Uplifted,Relaxed,Happy,Sleepy,Creative
# 4.3         Uplifted,Relaxed,Happy,Euphoric,Focused
# 4.4     Uplifted,Relaxed,Energetic,Euphoric,Focused
# 4.5     Uplifted,Talkative,Euphoric,Happy,Energetic
# 4.6         Uplifted,Relaxed,Happy,Euphoric,Focused
# 4.7          Uplifted,Relaxed,Euphoric,Tingly,Happy
# 4.8         Uplifted,Giggly,Happy,Relaxed,Talkative
# 4.9             Relaxed,Sleepy,Hungry,Happy,Aroused
# 5.0     Uplifted,Happy,Talkative,Energetic,Euphoric
#
#                              Flavor                        Breeders  \
# Rating
# 0.0              Pungent,Woody,Pine                         Unknown
# 3.3             Sweet,Grape,Flowery         Great White North Seeds
# 3.5              Sweet,Berry,Earthy                     Oregon OMMP
# 3.7              Sweet,Earthy,Woody                Medical Seeds Co
# 3.8            Woody,Flowery,Earthy             World of Seeds Bank
# 3.9              Sweet,Minty,Earthy                         Unknown
# 4.0              Woody,Sweet,Earthy                         THSeeds
# 4.1          Tropical,Pungent,Sweet        White Label Seed Company
# 4.2           Woody,Earthy,Tropical             World of Seeds Bank
# 4.3            Woody,Pungent,Earthy             World of Seeds Bank
# 4.4        Woody,Spicy/Herbal,Sweet                 Woodhorse Seeds
# 4.5          Tropical,Sweet,Ammonia             World of Seeds Bank
# 4.6            Sweet,Vanilla,Earthy                 Zion Botanicals
# 4.7     Tropical,Spicy/Herbal,Sweet                 Zion Botanicals
# 4.8      Woody,Spicy/Herbal,Flowery                         Unknown
# 4.9              Sweet,Nutty,Coffee  Vancouver Island Seed Company
# 5.0        Tropical,Berry,Blueberry                       Vodis USA
#
#                   LOCATION   effect_1   effect_2   effect_3   effect_4  \
# Rating
# 0.0             Washington  Talkative     Tingly   Uplifted   Uplifted
# 3.3       Omak, Washington     Tingly   Uplifted    Relaxed      Happy
# 3.5                 Oregon   Uplifted      Happy  Talkative  Energetic
# 3.7                  Spain    Relaxed     Tingly   Uplifted   Uplifted
# 3.8        Valencia, Spain    Relaxed  Talkative     Sleepy   Uplifted
# 3.9             Washington  Talkative   Uplifted   Uplifted   Uplifted
# 4.0     Tacoma, Washington  Talkative   Uplifted   Uplifted   Uplifted
# 4.1        Valencia, Spain   Uplifted   Uplifted   Uplifted   Uplifted
# 4.2       Washington State   Uplifted   Uplifted   Uplifted   Uplifted
# 4.3       Washington State   Uplifted   Uplifted   Uplifted   Uplifted
# 4.4             Washington   Uplifted   Uplifted   Uplifted   Uplifted
# 4.5             Washington   Uplifted   Uplifted   Uplifted   Uplifted
# 4.6       Washington State   Uplifted   Uplifted   Uplifted   Uplifted
# 4.7       Washington State   Uplifted   Uplifted   Uplifted   Uplifted
# 4.8       Washington State   Uplifted   Uplifted   Uplifted   Uplifted
# 4.9     Tacoma, Washington    Relaxed     Sleepy   Uplifted   Uplifted
# 5.0        Valencia, Spain   Uplifted   Uplifted   Uplifted   Uplifted
#
#         effect_5  flavor_1  flavor_2  flavor_3  num_effects  num_flavors
# Rating
# 0.0     Euphoric   Pungent     Woody     Sweet          5.0          3.0
# 3.3       Hungry     Sweet    Pepper       Tea          5.0          3.0
# 3.5       Tingly     Sweet    Orange    Earthy          5.0          3.0
# 3.7     Uplifted     Sweet   Pungent     Woody          5.0          4.0
# 3.8     Uplifted     Woody     Woody     Sweet          5.0          4.0
# 3.9     Uplifted     Sweet     Skunk     Woody          5.0          3.0
# 4.0     Uplifted     Woody  Tropical    Violet          5.0          3.0
# 4.1     Uplifted  Tropical     Woody     Woody          5.0          3.0
# 4.2     Uplifted     Woody     Woody     Woody          5.0          4.0
# 4.3     Uplifted     Woody     Woody     Woody          5.0          4.0
# 4.4     Uplifted     Woody     Woody     Woody          5.0          4.0
# 4.5     Uplifted  Tropical     Woody     Woody          5.0          3.0
# 4.6     Uplifted     Sweet     Woody     Woody          5.0          3.0
# 4.7     Uplifted  Tropical     Woody     Woody          5.0          3.0
# 4.8     Uplifted     Woody     Woody     Woody          5.0          4.0
# 4.9     Uplifted     Sweet     Sweet     Woody          5.0          3.0
# 5.0     Uplifted  Tropical  Tropical  Tropical          5.0          4.0
