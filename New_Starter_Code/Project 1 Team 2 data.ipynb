# %%
import pandas as pd

# %%
#HYPOTHESIS

#1) Misha
    #Do hybrid types have more happy effects compared to non-hybrid types?
        #Option 1: Create data frame from first 5 columns, then call columns needed to compare type with effect

    #Option 2: Group data by type and effect

    #Visual display of how many happy effects associated to each type - Donut Charts (3 total)
    
    #What is the correlation of type to effect-Use P-Values - Scatter Plot
        #Make sure to add statement - If P value is greater than x-value (look for this) there is a strong correlation

#2) Kim
    #Does sweet profile cannabis have a higher rating?
        #What Flavor had the Max Rating
        #What Flavor has the min Rating
        #What Flavor has the median Rating
    
#3) #Latti
    #Does the location of the breeder impact the rating? Does the location impact the type that is grown?


#4)  Tacha
    #Is there a significant difference in the effects experienced by consumers when they rate the same cannabis type differently? 
    #(Use data to get the ratings of the cannabis type and analyze the effects reported to see if they are consistent.) Do users feel different effects when they use the same type of cannabis(yes). How does this affect how they rate it? Ex: Hybrid- 13 users said it made them aroused. What is the average rating reported by those 13 people? Repeat for a few more effects in Hybrid, Sativa, then Indica.

# %%
Original_Data = pd.read_csv("new_data.csv",encoding='latin-1')
Original_Data.head()
# Out:
#            Strain    Type  Rating                                     Effects  \
# 0          100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1  98-White-Widow  hybrid     4.7    Relaxed,Aroused,Creative,Happy,Energetic
# 2            1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 3        13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 4        24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
#
#                       Flavor  \
# 0        Earthy,Sweet,Citrus
# 1      Flowery,Violet,Diesel
# 2    Spicy/Herbal,Sage,Woody
# 3  Apricot,Citrus,Grapefruit
# 4       Citrus,Earthy,Orange
#
#                                          Description  effect 1   effect 2  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...  Creative  Energetic
# 1  The â98 Aloha White Widow is an especially p...   Relaxed    Aroused
# 2  1024 is a sativa-dominant hybrid bred in Spain...  Uplifted      Happy
# 3  13 Dawgs is a hybrid of G13 and Chemdawg genet...    Tingly   Creative
# 4  Also known as Kosher Tangie, 24k Gold is a 60%...     Happy    Relaxed
#
#    effect 3   effect 4   effect 5      flavor 1 flavor 2    flavor 3  \
# 0    Tingly   Euphoric    Relaxed        Earthy    Sweet      Citrus
# 1  Creative      Happy  Energetic       Flowery   Violet      Diesel
# 2   Relaxed  Energetic   Creative  Spicy/Herbal     Sage       Woody
# 3    Hungry    Relaxed   Uplifted       Apricot   Citrus  Grapefruit
# 4  Euphoric   Uplifted  Talkative        Citrus   Earthy      Orange
#
#    num_effects  num_flavors
# 0          5.0          3.0
# 1          5.0          3.0
# 2          5.0          3.0
# 3          5.0          3.0
# 4          5.0          3.0

# %%
Original_Data.Effects.str.split(",",expand=True)
# Out:
#              0          1          2          3          4
# 0     Creative  Energetic     Tingly   Euphoric    Relaxed
# 1      Relaxed    Aroused   Creative      Happy  Energetic
# 2     Uplifted      Happy    Relaxed  Energetic   Creative
# 3       Tingly   Creative     Hungry    Relaxed   Uplifted
# 4        Happy    Relaxed   Euphoric   Uplifted  Talkative
# ...        ...        ...        ...        ...        ...
# 2048     Happy   Uplifted    Relaxed   Euphoric  Energetic
# 2049   Relaxed      Happy   Euphoric   Uplifted     Sleepy
# 2050   Relaxed     Sleepy  Talkative   Euphoric      Happy
# 2051   Relaxed     Sleepy   Euphoric      Happy     Hungry
# 2052    Hungry    Relaxed   Uplifted      Happy     Sleepy
#
# [2053 rows x 5 columns]

# %%
effects = Original_Data.Effects.str.split(",",expand=True)
effects.columns=["effect_1", "effect_2", "effect_3", "effect_4", "effect_5"]
effects.head()
# Out:
#    effect_1   effect_2  effect_3   effect_4   effect_5
# 0  Creative  Energetic    Tingly   Euphoric    Relaxed
# 1   Relaxed    Aroused  Creative      Happy  Energetic
# 2  Uplifted      Happy   Relaxed  Energetic   Creative
# 3    Tingly   Creative    Hungry    Relaxed   Uplifted
# 4     Happy    Relaxed  Euphoric   Uplifted  Talkative

# %%
flavors = Original_Data.Flavor.str.split(",",expand=True)
flavors.columns=["flavor_1", "flavor_2", "flavor_3", "flavor_4"]
flavors.head()
# Out:
#        flavor_1 flavor_2    flavor_3 flavor_4
# 0        Earthy    Sweet      Citrus     None
# 1       Flowery   Violet      Diesel     None
# 2  Spicy/Herbal     Sage       Woody     None
# 3       Apricot   Citrus  Grapefruit     None
# 4        Citrus   Earthy      Orange     None

# %%
flavors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   flavor_1  2053 non-null   object
#  1   flavor_2  2053 non-null   object
#  2   flavor_3  2053 non-null   object
#  3   flavor_4  39 non-null     object
# dtypes: object(4)
# memory usage: 64.3+ KB

# %%
pd.concat([df, effects, flavors], axis=1)
# Out:
#               Strain    Type  Rating  \
# 0             100-Og  hybrid     4.0
# 1     98-White-Widow  hybrid     4.7
# 2               1024  sativa     4.4
# 3           13-Dawgs  hybrid     4.2
# 4           24K-Gold  hybrid     4.6
# ...              ...     ...     ...
# 2048         Zeus-Og  hybrid     4.7
# 2049        Zkittlez  indica     4.6
# 2050     Zombie-Kush  indica     5.0
# 2051       Zombie-Og  indica     4.4
# 2052        Zoom-Pie  indica     4.6
#
#                                          Effects                     Flavor  \
# 0     Creative,Energetic,Tingly,Euphoric,Relaxed        Earthy,Sweet,Citrus
# 1       Relaxed,Aroused,Creative,Happy,Energetic      Flowery,Violet,Diesel
# 2      Uplifted,Happy,Relaxed,Energetic,Creative    Spicy/Herbal,Sage,Woody
# 3        Tingly,Creative,Hungry,Relaxed,Uplifted  Apricot,Citrus,Grapefruit
# 4      Happy,Relaxed,Euphoric,Uplifted,Talkative       Citrus,Earthy,Orange
# ...                                          ...                        ...
# 2048   Happy,Uplifted,Relaxed,Euphoric,Energetic          Earthy,Woody,Pine
# 2049      Relaxed,Happy,Euphoric,Uplifted,Sleepy          Sweet,Berry,Grape
# 2050     Relaxed,Sleepy,Talkative,Euphoric,Happy  Earthy,Sweet,Spicy/Herbal
# 2051        Relaxed,Sleepy,Euphoric,Happy,Hungry       Sweet,Earthy,Pungent
# 2052        Hungry,Relaxed,Uplifted,Happy,Sleepy       Berry,Earthy,Pungent
#
#                                             Description  effect 1   effect 2  \
# 0     $100 OG is a 50/50 hybrid strain that packs a ...  Creative  Energetic
# 1     The ‘98 Aloha White Widow is an especially pot...   Relaxed    Aroused
# 2     1024 is a sativa-dominant hybrid bred in Spain...  Uplifted      Happy
# 3     13 Dawgs is a hybrid of G13 and Chemdawg genet...    Tingly   Creative
# 4     Also known as Kosher Tangie, 24k Gold is a 60%...     Happy    Relaxed
# ...                                                 ...       ...        ...
# 2048  Zeus OG is a hybrid cross between Pineapple OG...     Happy   Uplifted
# 2049  Zkittlez is an indica-dominant mix of Grape Ap...   Relaxed      Happy
# 2050  Zombie Kush by Ripper Seeds comes from two dif...   Relaxed     Sleepy
# 2051  If you’re looking to transform into a flesh-ea...   Relaxed     Sleepy
# 2052  Zoom Pie (also known as Zombie Pie) is a heavy...    Hungry    Relaxed
#
#        effect 3   effect 4  ... num_flavors  effect_1   effect_2   effect_3  \
# 0        Tingly   Euphoric  ...         3.0  Creative  Energetic     Tingly
# 1      Creative      Happy  ...         3.0   Relaxed    Aroused   Creative
# 2       Relaxed  Energetic  ...         3.0  Uplifted      Happy    Relaxed
# 3        Hungry    Relaxed  ...         3.0    Tingly   Creative     Hungry
# 4      Euphoric   Uplifted  ...         3.0     Happy    Relaxed   Euphoric
# ...         ...        ...  ...         ...       ...        ...        ...
# 2048    Relaxed   Euphoric  ...         3.0     Happy   Uplifted    Relaxed
# 2049   Euphoric   Uplifted  ...         3.0   Relaxed      Happy   Euphoric
# 2050  Talkative   Euphoric  ...         3.0   Relaxed     Sleepy  Talkative
# 2051   Euphoric      Happy  ...         3.0   Relaxed     Sleepy   Euphoric
# 2052   Uplifted      Happy  ...         3.0    Hungry    Relaxed   Uplifted
#
#        effect_4   effect_5      flavor_1 flavor_2      flavor_3 flavor_4
# 0      Euphoric    Relaxed        Earthy    Sweet        Citrus     None
# 1         Happy  Energetic       Flowery   Violet        Diesel     None
# 2     Energetic   Creative  Spicy/Herbal     Sage         Woody     None
# 3       Relaxed   Uplifted       Apricot   Citrus    Grapefruit     None
# 4      Uplifted  Talkative        Citrus   Earthy        Orange     None
# ...         ...        ...           ...      ...           ...      ...
# 2048   Euphoric  Energetic        Earthy    Woody          Pine     None
# 2049   Uplifted     Sleepy         Sweet    Berry         Grape     None
# 2050   Euphoric      Happy        Earthy    Sweet  Spicy/Herbal     None
# 2051      Happy     Hungry         Sweet   Earthy       Pungent     None
# 2052      Happy     Sleepy         Berry   Earthy       Pungent     None
#
# [2053 rows x 25 columns]

# %%
#Clean original data and combined data frame of the flavors and effects into the original Data Frame
OD2=pd.concat([Original_Data, effects, flavors], axis=1)
OD2.head()
# Out:
#            Strain    Type  Rating                                     Effects  \
# 0          100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1  98-White-Widow  hybrid     4.7    Relaxed,Aroused,Creative,Happy,Energetic
# 2            1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 3        13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 4        24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
#
#                       Flavor  \
# 0        Earthy,Sweet,Citrus
# 1      Flowery,Violet,Diesel
# 2    Spicy/Herbal,Sage,Woody
# 3  Apricot,Citrus,Grapefruit
# 4       Citrus,Earthy,Orange
#
#                                          Description  effect 1   effect 2  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...  Creative  Energetic
# 1  The ‘98 Aloha White Widow is an especially pot...   Relaxed    Aroused
# 2  1024 is a sativa-dominant hybrid bred in Spain...  Uplifted      Happy
# 3  13 Dawgs is a hybrid of G13 and Chemdawg genet...    Tingly   Creative
# 4  Also known as Kosher Tangie, 24k Gold is a 60%...     Happy    Relaxed
#
#    effect 3   effect 4  ... num_flavors  effect_1   effect_2  effect_3  \
# 0    Tingly   Euphoric  ...         3.0  Creative  Energetic    Tingly
# 1  Creative      Happy  ...         3.0   Relaxed    Aroused  Creative
# 2   Relaxed  Energetic  ...         3.0  Uplifted      Happy   Relaxed
# 3    Hungry    Relaxed  ...         3.0    Tingly   Creative    Hungry
# 4  Euphoric   Uplifted  ...         3.0     Happy    Relaxed  Euphoric
#
#     effect_4   effect_5      flavor_1 flavor_2    flavor_3 flavor_4
# 0   Euphoric    Relaxed        Earthy    Sweet      Citrus     None
# 1      Happy  Energetic       Flowery   Violet      Diesel     None
# 2  Energetic   Creative  Spicy/Herbal     Sage       Woody     None
# 3    Relaxed   Uplifted       Apricot   Citrus  Grapefruit     None
# 4   Uplifted  Talkative        Citrus   Earthy      Orange     None
#
# [5 rows x 25 columns]

# %%
OD2["num_effects"]=df2.Effects.str.count(",")+1
OD2["num_flavors"]=df2.Flavor.str.count(",")+1
OD2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Strain       2053 non-null   object
#  1   Type         2053 non-null   object
#  2   Rating       2053 non-null   float64
#  3   Effects      2053 non-null   object
#  4   Flavor       2053 non-null   object
#  5   Description  2053 non-null   object
#  6   effect 1     2053 non-null   object
#  7   effect 2     2053 non-null   object
#  8   effect 3     2053 non-null   object
#  9   effect 4     2053 non-null   object
#  10  effect 5     2053 non-null   object
#  11  flavor 1     2053 non-null   object
#  12  flavor 2     2053 non-null   object
#  13  flavor 3     2053 non-null   object
#  14  num_effects  2053 non-null   int64
#  15  num_flavors  2053 non-null   int64
#  16  effect_1     2053 non-null   object
#  17  effect_2     2053 non-null   object
#  18  effect_3     2053 non-null   object
#  19  effect_4     2053 non-null   object
#  20  effect_5     2053 non-null   object
#  21  flavor_1     2053 non-null   object
#  22  flavor_2     2053 non-null   object
#  23  flavor_3     2053 non-null   object
#  24  flavor_4     39 non-null     object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 401.1+ KB

# %%
OD2["effect_1"].value_counts()
# Out:
# effect_1
# Relaxed      800
# Happy        449
# Euphoric     227
# Uplifted     215
# Creative      65
# Energetic     64
# Sleepy        62
# Focused       44
# Talkative     41
# Aroused       29
# Hungry        28
# Tingly        22
# Giggly         7
# Name: count, dtype: int64

# %%
#Remove null values - Flavor4
OD2=OD2.drop(columns=["flavor_4"])
OD3=OD2.dropna(how="any")
OD3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Strain       2053 non-null   object
#  1   Type         2053 non-null   object
#  2   Rating       2053 non-null   float64
#  3   Effects      2053 non-null   object
#  4   Flavor       2053 non-null   object
#  5   Description  2053 non-null   object
#  6   effect 1     2053 non-null   object
#  7   effect 2     2053 non-null   object
#  8   effect 3     2053 non-null   object
#  9   effect 4     2053 non-null   object
#  10  effect 5     2053 non-null   object
#  11  flavor 1     2053 non-null   object
#  12  flavor 2     2053 non-null   object
#  13  flavor 3     2053 non-null   object
#  14  num_effects  2053 non-null   int64
#  15  num_flavors  2053 non-null   int64
#  16  effect_1     2053 non-null   object
#  17  effect_2     2053 non-null   object
#  18  effect_3     2053 non-null   object
#  19  effect_4     2053 non-null   object
#  20  effect_5     2053 non-null   object
#  21  flavor_1     2053 non-null   object
#  22  flavor_2     2053 non-null   object
#  23  flavor_3     2053 non-null   object
# dtypes: float64(1), int64(2), object(21)
# memory usage: 385.1+ KB

# %%
#We droped 12% of null values so 88% of our data is valid
#(2351-2053)/2351
# Out:
# 0.1267545725223309

# %%
#fIND TOTAL VALUES FOR EACH TYPE
OD3.Type.value_counts()
# Out:
# Type
# hybrid    1045
# indica     621
# sativa     387
# Name: count, dtype: int64

# %%
#Find average rating for each
OD3.groupby("Type").Rating.mean()
# Out:
# Type
# hybrid    4.440096
# indica    4.447987
# sativa    4.433333
# Name: Rating, dtype: float64

# %%
#COUNT FOR EACH EFFECT FOR EFFECT1 BY TYPE
OD3.groupby(["Type", "effect_1"]).size()
# Out:
# Type    effect_1
# hybrid  Aroused       13
#         Creative      36
#         Energetic     25
#         Euphoric     125
#         Focused       26
#         Giggly         3
#         Happy        286
#         Hungry        15
#         Relaxed      346
#         Sleepy        22
#         Talkative     29
#         Tingly        12
#         Uplifted     107
# indica  Aroused       11
#         Creative       7
#         Energetic      2
#         Euphoric      53
#         Focused        4
#         Giggly         3
#         Happy         51
#         Hungry        10
#         Relaxed      420
#         Sleepy        36
#         Talkative      2
#         Tingly         6
#         Uplifted      16
# sativa  Aroused        5
#         Creative      22
#         Energetic     37
#         Euphoric      49
#         Focused       14
#         Giggly         1
#         Happy        112
#         Hungry         3
#         Relaxed       34
#         Sleepy         4
#         Talkative     10
#         Tingly         4
#         Uplifted      92
# dtype: int64

# %%
#df3.to_csv("MaryJane_clean_data.csv", index=False)
